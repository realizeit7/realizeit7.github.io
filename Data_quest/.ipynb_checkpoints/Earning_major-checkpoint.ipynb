# %% [markdown]
# # Data visualization
# ## -Earnings based on college majors

# %%
import pandas as pd
import matplotlib.pyplot as plt
recent_grads=pd.read_csv("recent-grads.csv") #Importing data
recent_grads.iloc[0] #show first row
recent_grads.head()  #first 5 row
recent_grads.tail()  #last 5 row
recent_grads.describe() #summary stats
raw_data_count=recent_grads.shape[0] # number of rows
print(raw_data_count)
recent_grads=recent_grads.dropna() #droping rows with missing
cleaned_data_count=recent_grads.shape[0]
print(cleaned_data_count)
# Out:
# 173
# 172

# %% [markdown]
# There is only one row with missing value.

# %% [markdown]
# ### Scatter plots to explore data.

# %%
ax = recent_grads.plot(x='Sample_size', y='Median', kind='scatter') #scatter plot
ax.set_title('Median vs. Sample_size') #title
# Out:
# Text(0.5, 1.0, 'Median vs. Sample_size')

# %%
ax = recent_grads.plot(x='Sample_size', y='Unemployment_rate', kind='scatter')
ax.set_title('Unemployment_rate vs. Sample_size')
# Out:
# Text(0.5, 1.0, 'Unemployment_rate vs. Sample_size')

# %%
ax = recent_grads.plot(x='Full_time', y='Median', kind='scatter')
ax.set_title('Median vs. Full_time')
# Out:
# Text(0.5, 1.0, 'Median vs. Full_time')

# %%
ax = recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter')
ax.set_title('Unemployment_rate vs. ShareWomen')
# Out:
# Text(0.5, 1.0, 'Unemployment_rate vs. ShareWomen')

# %%
ax = recent_grads.plot(x='Men', y='Median', kind='scatter')
ax.set_title('Median vs. Men')
# Out:
# Text(0.5, 1.0, 'Median vs. Men')

# %%
ax = recent_grads.plot(x='Women', y='Median', kind='scatter')
ax.set_title('Median vs. Women')
# Out:
# Text(0.5, 1.0, 'Median vs. Women')

# %% [markdown]
# ### Histogram for each variables

# %%
ax=recent_grads['Median'].plot(kind='hist') #histogram
ax.set_title('Median') #title
# Out:
# Text(0.5, 1.0, 'Median')

# %%
ax=recent_grads['Full_time'].plot(kind='hist')
ax.set_title('Full_time')
# Out:
# Text(0.5, 1.0, 'Full_time')

# %%
ax=recent_grads['ShareWomen'].plot(kind='hist')
ax.set_title('ShareWomen')
# Out:
# Text(0.5, 1.0, 'ShareWomen')

# %%
ax=recent_grads['Unemployment_rate'].plot(kind='hist')
ax.set_title('Unemployment_rate')
# Out:
# Text(0.5, 1.0, 'Unemployment_rate')

# %%
ax=recent_grads['Men'].plot(kind='hist')
ax.set_title('Men')
# Out:
# Text(0.5, 1.0, 'Men')

# %%
ax=recent_grads['Women'].plot(kind='hist')
ax.set_title('Women')
# Out:
# Text(0.5, 1.0, 'Women')

# %% [markdown]
# ### Plotting univariate histogram and bivariate scatterplot in a single plot

# %%
from pandas.plotting import scatter_matrix #need scatter_matrix from pandas.plotting
scatter_matrix(recent_grads[['Sample_size', 'Median']],figsize=(10,10)) 
#showing both hist and scatter
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x119895588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119b0ad30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x119b3ca20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118fbb828>]],
#       dtype=object)

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(recent_grads[['Sample_size', 'Median','Unemployment_rate']],figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x107163e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119308978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1194e7f28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x119344518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1193acac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11944c0b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11a892668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119a9ac50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x119a9ac88>]],
#       dtype=object)

# %% [markdown]
# ### Proportion of women in each major.

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen', legend=False) #bar chart for first 10 major
recent_grads[163:].plot.bar(x='Major', y='ShareWomen', legend=False) #bar chart for last 10 major
